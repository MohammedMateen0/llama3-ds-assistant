# %%
# !pip install unsloth
# !pip install transformers
# !pip install datasets
# !pip install trl
# !pip install peft
# !pip install accelerate

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from unsloth import FastLanguageModel
model,tokenizer=FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-1B-Instruct",
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True
)
# Out:
# ==((====))==  Unsloth 2026.6.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# <string>:42: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Unsloth: Will load unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit as a legacy tokenizer.

# %%
model=FastLanguageModel.get_peft_model(
    model,
    r=16,
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj"
    ],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth"
)

# %%
FastLanguageModel.for_inference(model)
prompt='''What is LoRA?'''

inputs=tokenizer(
    prompt,
    return_tensors="pt"
).to("cuda")
outputs=model.generate(
    **inputs,
    max_new_tokens=150,
    temperature=0.7
)
print(
    tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )
)
# Out:
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# ...

# %%
FastLanguageModel.for_inference(model)
prompt='''What is QLoRA?'''

inputs=tokenizer(
    prompt,
    return_tensors="pt"
).to("cuda")
outputs=model.generate(
    **inputs,
    max_new_tokens=150,
    temperature=0.7
)
print(
    tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )
)
# Out:
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# What is QLoRA? QLoRA is a 3D scanning technology developed by the University of California, Los Angeles (UCLA) that allows for the creation of high-resolution 3D models of objects with minimal loss of accuracy.
# QLoRA stands for Quadricentric LoRa, but it's more accurate to say that it is Quadricentric LoRa because it is a quadricentric system, meaning it relies on a combination of four sensors to achieve its scanning capabilities. This allows QLoRA to scan objects at a high resolution and with minimal loss of accuracy. The system uses a combination of ultrasonic sensors and cameras to create the 3D model of the object. The system is relatively new and is being developed by researchers at UCLA.
# QLo

# %%
FastLanguageModel.for_inference(model)
prompt='''Why does LoRA initialize B to zero?'''

inputs=tokenizer(
    prompt,
    return_tensors="pt"
).to("cuda")
outputs=model.generate(
    **inputs,
    max_new_tokens=150,
    temperature=0.7
)
print(
    tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )
)
# Out:
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Why does LoRA initialize B to zero? This is not a typical behavior in most cases. In general, when LoRA is initialized, the B register is initialized to a specific value, usually 0 or 1. However, there is a specific scenario where LoRA is initialized to zero, which is when the LoRA is configured as a synchronous receiver.
#
# When LoRA is configured as a synchronous receiver, the B register is initialized to zero. This is because the synchronous receiver mode requires that the B register be set to zero before the LoRA can start transmitting data.
#
# In summary, LoRA initializes B to zero in the following scenarios:
#
# 1. When LoRA is configured as a synchronous receiver.
# 2. When LoRA is not in the reset mode (i.e., it is

# %%
FastLanguageModel.for_inference(model)
prompt='''Why is DPO more stable than RLHF?'''

inputs=tokenizer(
    prompt,
    return_tensors="pt"
).to("cuda")
outputs=model.generate(
    **inputs,
    max_new_tokens=150,
    temperature=0.7
)
print(
    tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )
)
# Out:
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Why is DPO more stable than RLHF? At what point does the stability of DPO begin to decrease?
# The stability of DPO is lower than that of RLHF due to the difference in the energy levels of the excited states. Specifically, the energy levels of the excited states in DPO are more closely spaced than those in RLHF, leading to a greater probability of transition to the ground state. Therefore, the probability of excited state transitions is higher in DPO, and the probability of excited state absorption is lower. This results in a lower overall stability of DPO.
# ...

# %%
from datasets import load_dataset

dataset=load_dataset(
    "json",
    data_files="ds_qa.json"
)

# %%
print(dataset)
print(dataset["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'response'],
#         num_rows: 345
#     })
# })
# {'instruction': 'What is the difference between supervised and unsupervised learning?', 'response': 'Supervised learning uses labeled training data to predict outcomes, while unsupervised learning identifies hidden patterns or structures in unlabeled data.'}

# %%
def format_example(example):
  message=[{
      "role":"user",
      "content":example["instruction"]
  },
      {
          "role":"assistant",
          "content":example["response"]
      }
  ]
  text=tokenizer.apply_chat_template(
      message,
      tokenize=False,
      add_generation_prompt=False
  )
  return {"text":text}

dataset = dataset["train"].map(format_example)

# %%
print(dataset[0]["text"])
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 21 Jun 2026
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is the difference between supervised and unsupervised learning?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Supervised learning uses labeled training data to predict outcomes, while unsupervised learning identifies hidden patterns or structures in unlabeled data.<|eot_id|>

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

# %%
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=2048,
    packing=False,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=5,
        num_train_epochs=5,
        learning_rate=1e-4,
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=42,
        save_strategy="no",
        output_dir="outputs",
        report_to="none",
    ),
)

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 345 | Num Epochs = 5 | Total steps = 220
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 11,272,192 of 1,247,086,592 (0.90% trained)
#     <div>
#
#       <progress value='220' max='220' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [220/220 02:27, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.661645</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.634473</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.786895</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.477115</td>
#     </tr>
# ...

# %%
model.save_pretrained(
    "llama_ds_lora"
)

tokenizer.save_pretrained(
    "llama_ds_lora"
)
# Out:
# ('llama_ds_lora/tokenizer_config.json',
#  'llama_ds_lora/chat_template.jinja',
#  'llama_ds_lora/tokenizer.json')

# %%
FastLanguageModel.for_inference(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 2048, padding_idx=128004)
#         (layers): ModuleList(
#           (0): LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
# ...

# %%
import os

for file in os.listdir("llama_ds_lora"):
    print(file)
# Out:
# chat_template.jinja
# tokenizer_config.json
# README.md
# tokenizer.json
# adapter_config.json
# adapter_model.safetensors

# %%
prompts=["What is LoRA?","What is QLoRA?","Why does LoRA initialize B to zero?","Why is DPO more stable than RLHF?"]
with
for prompt in prompts:
  inputs=tokenizer(
    prompt,
    return_tensors="pt"
).to("cuda")

  outputs=model.generate(
    **inputs,
    max_new_tokens=100,
    temperature=0.1
  )
  print(tokenizer.decode(
    outputs[0],
    skip_special_tokens=True
  ))
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# ...

# %%
# !ls -lh llama_ds_lora
# Out:
# total 60M
# -rw-r--r-- 1 root root 1.3K Jun 21 10:21 adapter_config.json
# -rw------- 1 root root  44M Jun 21 10:21 adapter_model.safetensors
# -rw-r--r-- 1 root root 3.8K Jun 21 10:21 chat_template.jinja
# -rw-r--r-- 1 root root 5.2K Jun 21 10:21 README.md
# -rw-r--r-- 1 root root  50K Jun 21 10:21 tokenizer_config.json
# -rw-r--r-- 1 root root  17M Jun 21 10:21 tokenizer.json

# %%
from huggingface_hub import logout

logout()

# %%
from huggingface_hub import whoami

print(whoami())
# Out:
# {'type': 'user', 'id': '6a37a35973d2828187855dde', 'name': 'mateen-2003', 'fullname': 'Mohammed Mateen', 'isPro': False, 'avatarUrl': '/avatars/90313259c80641c8af43f9c319dd0be8.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'experiment', 'role': 'fineGrained', 'createdAt': '2026-06-21T10:16:48.158Z', 'fineGrained': {'canReadGatedRepos': False, 'global': [], 'scoped': [{'entity': {'_id': '6a37a35973d2828187855dde', 'type': 'user', 'name': 'mateen-2003'}, 'permissions': []}]}}}}

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from huggingface_hub import create_repo
create_repo(
    "llama3-ds-assistant",
    exist_ok=True
)
# Out:
# RepoUrl('https://huggingface.co/mateen-2003/llama3-ds-assistant', endpoint='https://huggingface.co', repo_type='model', repo_id='mateen-2003/llama3-ds-assistant')

# %%
model.push_to_hub(
    "mateen-2003/llama3-ds-assistant"
)

tokenizer.push_to_hub(
    "mateen-2003/llama3-ds-assistant"
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...adapter_model.safetensors:   0%|          | 23.3kB / 45.1MB
# Saved model to https://huggingface.co/mateen-2003/llama3-ds-assistant
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# Unsloth: Restored added_tokens_decoder metadata in /tmp/tmpyb35jq58/tokenizer_config.json.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...mpyb35jq58/tokenizer.json: 100%|##########| 17.2MB / 17.2MB

# %%
from unsloth import FastLanguageModel

model, tokenizer = FastLanguageModel.from_pretrained(
    "mateen-2003/llama3-ds-assistant",
    load_in_4bit=True
)
# Out:
# ==((====))==  Unsloth 2026.6.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# <string>:42: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Unsloth: Will load unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit as a legacy tokenizer.
# adapter_model.safetensors:   0%|          | 0.00/45.1M [00:00<?, ?B/s]
